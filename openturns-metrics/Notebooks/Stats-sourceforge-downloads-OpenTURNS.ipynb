# %% [markdown]
# # Sourceforge OpenTURNS downloads statistics
#
# This document gathers download statistics on Sourceforge.
#
# ## References
#
# https://sourceforge.net/projects/openturns/files/openturns/stats/timeline?dates=2007-06-01%20to%202020-05-01&period=monthly

# %%
import pylab as pl
import numpy as np
import openturns as ot
import pandas as pd
import openturns.viewer as otv

# %%
df = pd.read_csv("../data/Sourceforge-Downloads-2007-06-to-2020-05.csv", index_col=0)
df
# Out:
#          Downloads
# Month
# 2007-06         24
# 2007-07         50
# 2007-08         39
# 2007-09         71
# 2007-10         63
# ...            ...
# 2020-01         13
# 2020-02          4
# 2020-03         14
# 2020-04         10
# 2020-05          4
#
# [156 rows x 1 columns]

# %%
df.plot(figsize=(7,5));
pl.title("OpenTURNS Sourceforge Downloads from %s to %s" % (df.index[0], df.index[-1]));
pl.savefig("../figures/openturns-sourceforge-downloads.png")
pl.savefig("../figures/openturns-sourceforge-downloads.pdf")
