# %% [markdown]
# # Google Scholar references for OpenTURNS
#
# In Google Scholar, we searched for "openturns uncertainties" from 2007 to 2019.
#
# ## References
#
# https://scholar.google.fr/scholar?q=openturns+uncertainties&hl=fr&as_sdt=1%2C5&as_vis=1&as_ylo=2019&as_yhi=2019

# %%
import numpy as np
import openturns as ot
import openturns.viewer as otv

# %%
data = [[2007, 5],
        [2008, 3],
        [2009, 13],
        [2010, 15],
        [2011, 20],
        [2012, 20],
        [2013, 31],
        [2014, 33],
        [2015, 35],
        [2016, 39],
        [2017, 40],
        [2018, 57],
        [2019, 58],
        [2020, 62],
        [2021, 75],        
        [2022, 94],        
       ]

data = np.array(data)

sample = ot.Sample(data)
sample.setDescription(["Year", "Google Scholar"])

# %%
graph = ot.Graph("References of \"openturns uncertainties\" on Google Scholar",
                 "Year", "Annual number", True)
cloud = ot.Cloud(sample)
cloud.setPointStyle("circle")
graph.add(cloud)
graph.setColors(ot.Drawable_BuildDefaultPalette(1))
graph
# Out:
# class=Graph name=References of "openturns uncertainties" on Google Scholar implementation=class=GraphImplementation name=References of "openturns uncertainties" on Google Scholar title=References of "openturns uncertainties" on Google Scholar xTitle=Year yTitle=Annual number axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=16 dimension=2 description=[Year,Google Scholar] data=[[2007,5],[2008,3],[2009,13],[2010,15],[2011,20],[2012,20],[2013,31],[2014,33],[2015,35],[2016,39],[2017,40],[2018,57],[2019,58],[2020,62],[2021,75],[2022,94]] color=#1f77b4 fillStyle=solid lineStyle=solid pointStyle=circle lineWidth=1]

# %%
view = otv.View(graph)
view.save("openturns-googlescholar.png")
