# %%
import openturns as ot
from IPython.display import display, HTML

ot.Log.Show(ot.Log.NONE)

# %%
ot.RandomGenerator.SetSeed(0)
dimension = 2
input_names = ["x1", "x2"]
formulas = ["cos(x1 + x2)", "(x2 + 1) * exp(x1 - 2 * x2)"]
model = ot.SymbolicFunction(input_names, formulas)
distribution = ot.Normal(dimension)
x = distribution.getSample(30)
y = model(x)

algo = ot.FunctionalChaosAlgorithm(x, y, distribution)
algo.run()

chaosResult = algo.getResult()

# %%
composedMetamodel = chaosResult.getComposedMetaModel()
print(type(composedMetamodel))
composedMetamodel
# Out:
# <class 'openturns.func.DualLinearCombinationFunction'>
# ...

# %%
print(type(composedMetamodel))
# Out:
# <class 'openturns.func.DualLinearCombinationFunction'>

# %%
composedMetamodel([1.0, 1.0])
# Out:
# class=Point name=Unnamed dimension=2 values=[-0.400579,0.58735]

# %%
raw = ""
raw += "[0.00304403,1.45374] "
raw += "+ [-0.766216,-8.21324] * x0 "
raw += "+ [-1.06414,-3.43407] * (-0.707107 + 0.707107 * x1^2)"
print(raw)
# Out:
# [0.00304403,1.45374] + [-0.766216,-8.21324] * x0 + [-1.06414,-3.43407] * (-0.707107 + 0.707107 * x1^2)

# %%
html = ""
html += "[0.00304403,1.45374] "
html += "+ [-0.766216,-8.21324] × X<sub>0</sub>"
html += "+ [-1.06414,-3.43407] × (-0.707107 + 0.707107 × X<sub>1</sub><sup>2</sup>)"
html
# Out:
# '[0.00304403,1.45374] + [-0.766216,-8.21324] × X<sub>0</sub>+ [-1.06414,-3.43407] × (-0.707107 + 0.707107 × X<sub>1</sub><sup>2</sup>)'

# %%
display(HTML(html))
# Out:
# [0.00304403,1.45374] + [-0.766216,-8.21324] × X<sub>0</sub>+ [-1.06414,-3.43407] × (-0.707107 + 0.707107 × X<sub>1</sub><sup>2</sup>)

# %%
implementation = composedMetamodel.getImplementation()
print(type(implementation))
implementation
# Out:
# <class 'openturns.func.FunctionImplementation'>
# ...

# %%
evaluation = implementation.getEvaluation()
print(type(evaluation))
evaluation
# Out:
# <class 'openturns.func.Evaluation'>
# ...

# %%
evaluationImplementation = evaluation.getImplementation()
print(type(evaluationImplementation))
evaluationImplementation
# Out:
# <class 'openturns.func.DualLinearCombinationEvaluation'>
# ...

# %%
evaluationImplementation.getFunctionsCollection()
# Out:
# [class=Function name=Unnamed implementation=class=FunctionImplementation name=Unnamed description=[x0,x1,y0] evaluationImplementation=class=ProductPolynomialEvaluation, polynomials=[class=UniVariatePolynomial coefficients=class=Point name=Unnamed dimension=1 values=[1],class=UniVariatePolynomial coefficients=class=Point name=Unnamed dimension=1 values=[1]] gradientImplementation=class=ProductPolynomialGradient hessianImplementation=class=ProductPolynomialHessian,class=Function name=Unnamed implementation=class=FunctionImplementation name=Unnamed description=[x0,x1,y0] evaluationImplementation=class=ProductPolynomialEvaluation, polynomials=[class=UniVariatePolynomial coefficients=class=Point name=Unnamed dimension=2 values=[0,1],class=UniVariatePolynomial coefficients=class=Point name=Unnamed dimension=1 values=[1]] gradientImplementation=class=ProductPolynomialGradient hessianImplementation=class=ProductPolynomialHessian,class=Function name=Unnamed implementation=class=FunctionImplem
# ...
